# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
training_data = pd.read_csv('0000000000002747_training_twitter_x_y_train.csv')

# %%
training_data
# Out:
#                  tweet_id airline_sentiment     airline  \
# 0      567900433542488064          negative   Southwest
# 1      569989168903819264          positive   Southwest
# 2      568089179520954368          positive      United
# 3      568928195581513728          negative   Southwest
# 4      568594180014014464          negative      United
# ...                   ...               ...         ...
# 10975  569934458364813313           neutral    American
# 10976  568564006329434113          positive      United
# 10977  569643648910028801          negative  US Airways
# 10978  568864981917110272          negative  US Airways
# 10979  568929299350179840          negative      United
#
#       airline_sentiment_gold           name negativereason_gold  \
# 0                        NaN  ColeyGirouard                 NaN
# 1                        NaN  WalterFaddoul                 NaN
# 2                        NaN      LocalKyle                 NaN
# ...

# %%
testing_data = pd.read_csv('0000000000002747_test_twitter_x_test.csv')

# %%
testing_data
# Out:
#                 tweet_id         airline airline_sentiment_gold  \
# 0     569682010270101504        American                    NaN
# 1     569608307184242688        American                    NaN
# 2     567879304593408001       Southwest                    NaN
# 3     569757651539660801      US Airways                    NaN
# 4     569900705852608513        American                    NaN
# ...                  ...             ...                    ...
# 3655  570304244001193984      US Airways                    NaN
# 3656  567847737061941249      US Airways                    NaN
# 3657  567823564167192576  Virgin America                    NaN
# 3658  570273819287531520        American                    NaN
# 3659  569341769114128386          United                    NaN
#
#                  name negativereason_gold  retweet_count  \
# 0            zsalim03                 NaN              0
# 1            sa_craig                 NaN              0
# ...

# %% [markdown]
# ### I am going to use text column and airline_sentiment for building model

# %%
x_train = list(training_data['text'])
y_train = list(training_data['airline_sentiment'])
x_test = list(testing_data['text'])

# %%
x_train
# Out:
# ['@SouthwestAir I am scheduled for the morning, 2 days after the fact, yes..not sure why my evening flight was the only one Cancelled Flightled',
#  '@SouthwestAir seeing your workers time in and time out going above and beyond is why I love flying with you guys. Thank you!',
#  '@united Flew ORD to Miami and back and  had great crew, service on both legs. THANKS',
#  "@SouthwestAir @dultch97 that's horse radish 😤🐴",
#  '@united so our flight into ORD was delayed because of Air Force One, but the last flight to SBN is at 8:20, 5 mins from now we just landed.',
#  '@united Why did you load us in this flying sardine can if you knew the pilots were 2 hours Late Flight?? #incompetent beyond belief',
#  "@JetBlue that is a stock response. Delays not as frustrating as poor cust serv &amp; being told by 3 ppl to wait &amp; they'd come back but did not.",
#  "@JetBlue That'd be nice! Hoping to rack up enough miles to take a trip to Seattle and enjoy a perfect latte in the city of coffee.",
# ...

# %%
y_train
# Out:
# ['negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
# ...

# %% [markdown]
# ### For training the model better I am going to combine x_train and x_test

# %%
tweets_text = x_train + x_test

# %%
words_list = [word_tokenize(text.lower()) for text in tweets_text]

# %%
words_list
# Out:
# [['@',
#   'southwestair',
#   'i',
#   'am',
#   'scheduled',
#   'for',
#   'the',
#   'morning',
#   ',',
#   '2',
#   'days',
#   'after',
#   'the',
#   'fact',
#   ',',
#   'yes',
#   '..',
#   'not',
#   'sure',
#   'why',
#   'my',
#   'evening',
#   'flight',
#   'was',
#   'the',
#   'only',
#   'one',
#   'cancelled',
#   'flightled'],
#  ['@',
#   'southwestair',
#   'seeing',
#   'your',
#   'workers',
#   'time',
#   'in',
#   'and',
#   'time',
#   'out',
#   'going',
#   'above',
#   'and',
#   'beyond',
#   'is',
#   'why',
#   'i',
#   'love',
#   'flying',
#   'with',
#   'you',
#   'guys',
#   '.',
#   'thank',
#   'you',
#   '!'],
#  ['@',
#   'united',
#   'flew',
#   'ord',
#   'to',
#   'miami',
#   'and',
#   'back',
#   'and',
#   'had',
#   'great',
#   'crew',
#   ',',
#   'service',
#   'on',
#   'both',
#   'legs',
#   '.',
#   'thanks'],
#  ['@', 'southwestair', '@', 'dultch97', 'that', "'s", 'horse', 'radish', '😤🐴'],
#  ['@',
#   'united',
#   'so',
# ...

# %%
stop = stopwords.words('english')
punctuations = list(string.punctuation) #The punctuations in the string library is of the datatype string, so converting it into list to add it in the stopwords list
stop = stop + punctuations

# %%
stop
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %% [markdown]
# ### Data Cleaning: Removing stopwords and lemmatize the word

# %%
def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
lemmatizer = WordNetLemmatizer()

# %%
def clean_review(words):
    output_words = []
    for w in words:
        if w.lower() not in stop and w.lower()[0] != '/' and w.lower() != 'https' and w.lower() != 'htpp':
            pos = pos_tag([w])
            clean_word = lemmatizer.lemmatize(w,pos=get_simple_pos(pos[0][1]))
            output_words.append(clean_word.lower())
    return output_words

# %%
clean_word_list = [clean_review(word) for word in words_list]

# %%
#Convert array of words into single text
clean_text = [" ".join(word) for word in clean_word_list]

# %%
x_train_words = clean_text[0:10980]
x_test_words = clean_text[10980:]

# %%
count_vec = CountVectorizer(max_features=2000,ngram_range=(1,3),min_df=0.002,max_df=0.95)
x_train_final_features = count_vec.fit_transform(x_train_words)

# %%
count_vec.get_feature_names()
# Out:
# ['000',
#  '10',
#  '100',
#  '11',
#  '12',
#  '15',
#  '1k',
#  '1st',
#  '1st class',
#  '20',
#  '20 min',
#  '20 minute',
#  '200',
#  '2015',
#  '23',
#  '24',
#  '25',
#  '2nd',
#  '30',
#  '30 min',
#  '30 minute',
#  '40',
#  '40 minute',
#  '45',
#  '45 min',
#  '45 minute',
#  '50',
#  '75',
#  '800',
#  '90',
#  'aa',
#  'able',
#  'able get',
#  'absolutely',
#  'acceptable',
#  'access',
#  'account',
#  'actually',
#  'add',
#  'address',
#  'afternoon',
#  'agent',
#  'ago',
#  'air',
#  'aircraft',
#  'airline',
#  'airport',
#  'airway',
#  'all',
#  'allow',
#  'almost',
#  'already',
#  'also',
#  'always',
#  'amaze',
#  'american',
#  'americanair',
#  'americanair cancel',
#  'americanair flight',
#  'americanair get',
#  'americanair need',
#  'americanair thank',
#  'americanair thanks',
#  'americanair try',
#  'americanair usairways',
#  'americanair ve',
#  'americanair yes',
#  'amp',
#  'another',
#  'another airline',
#  'another flight',
#  'answer',
# ...

# %%
x_test_final_features = count_vec.transform(x_test_words)

# %% [markdown]
# ### Using Random Forest Classifier

# %%
rfc_clf = RandomForestClassifier(n_estimators=500)
rfc_clf.fit(x_train_final_features,y_train)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
y_pred_rfc = rfc_clf.predict(x_test_final_features)

# %%
np.savetxt("sentiments_predictions.csv",y_pred, delimiter=',', fmt="%s")
